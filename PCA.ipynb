# %% [markdown]
# # PCA Code:

# %%
import numpy as np 
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns

from sklearn.decomposition import PCA
from sympy import Matrix, init_printing,Symbol
from numpy.linalg import qr,eig,inv,matrix_rank,inv, norm
from scipy.linalg import null_space
init_printing()

# %%
def plot_2da(dict_):
    for key, value in dict_.items():
        plt.scatter(value[:, 0], value[:, 1],label=key)
    plt.legend()
    plt.show()
    
def plot_2db(dict_):
    for key, value in dict_.items():
        if value.shape[0]>2:
            plt.scatter(value[:, 0], value[:, 1],label=key)
        else:
            print(value)
            plt.quiver([0],[0],value[:,0],value[:,1],label=key)
    plt.legend()
    plt.show()

# %%
A=np.array([[2,-3],[4,7]])

Matrix(A)
# Out:
# ⎡2  -3⎤
# ⎢     ⎥
# ⎣4  7 ⎦

# %%
a1=A[:,0]
a1
# Out:
# array([2, 4])

# %%
a2=A[:,1]
a2
# Out:
# array([-3,  7])

# %%
AT=A.T
Matrix(AT)
# Out:
# ⎡2   4⎤
# ⎢     ⎥
# ⎣-3  7⎦

# %%
matrix_rank(A)
# Out:
# np.int64(2)

# %%
fig, ax = plt.subplots(figsize = (12, 7))

ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=30,label="$\mathbf{a}_{1}$")
ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=30,label="$\mathbf{a}_{2}$",color='red')
plt.title("columns of $\mathbf{A}$ ")
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\3086253123.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=30,label="$\mathbf{a}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\3086253123.py:4: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=30,label="$\mathbf{a}_{2}$",color='red')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\3086253123.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("columns of $\mathbf{A}$ ")

# %%
F=np.array([[2,4],[4,8]])
matrix_rank(F)
# Out:
# np.int64(1)

# %%
fig, ax = plt.subplots(figsize = (12, 7))
ax.quiver([0, 0],[0, 0],F[0,1], F[1,1],scale=30,label="$\mathbf{f}_{2}$",color='red')
ax.quiver([0, 0],[0, 0],F[0,0], F[1,0],scale=30,label="$\mathbf{f}_{1}$")
plt.title("columns of $\mathbf{F}$ ")
plt.legend()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2808504675.py:2: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],F[0,1], F[1,1],scale=30,label="$\mathbf{f}_{2}$",color='red')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2808504675.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],F[0,0], F[1,0],scale=30,label="$\mathbf{f}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2808504675.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("columns of $\mathbf{F}$ ")

# %%
G=np.array([[2,4,6],[6,4,2],[16,16,16]])

print(G)
print('Rank is:')
print(matrix_rank(G))
# Out:
# [[ 2  4  6]
#  [ 6  4  2]
#  [16 16 16]]
# Rank is:
# 2

# %%
F=np.array([[1,2],[1,-2],[-1,1]])
Matrix(F)
# Out:
# ⎡1   2 ⎤
# ⎢      ⎥
# ⎢1   -2⎥
# ⎢      ⎥
# ⎣-1  1 ⎦

# %%
ax = plt.figure().add_subplot(projection='3d')
p=null_space(F.T)
xx, yy = np.meshgrid(np.arange(-3,3,0.1), np.arange(-3,3,0.1))
z=(p[0]*xx+p[1]*yy)/p[2]
ax.plot_surface(xx, yy, z, alpha=0.1)
ax.quiver([0,0], [0,0], [0,0], F[0,:], F[1,:], F[2,:])

ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])
plt.show()

# %%
matrix_rank(F)
# Out:
# np.int64(2)

# %% [markdown]
# ### Frobenius norm of a matrix

# %%
Matrix(A), norm(A)
# Out:
# ⎛⎡2  -3⎤                   ⎞
# ⎜⎢     ⎥, 8.831760866327848⎟
# ⎝⎣4  7 ⎦                   ⎠

# %%
m, n = A.shape[0], A.shape[1] # get number of rows and columns 
sumsquares = 0

for i in range(m):
    for j in range(n):
        sumsquares += A[i,j] ** 2
np.sqrt(sumsquares)
# Out:
# np.float64(8.831760866327848)

# %%
B=np.array([[1,1],[1,-1]])
Matrix(B)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %%
C=A+B
Matrix(C)
# Out:
# ⎡3  -2⎤
# ⎢     ⎥
# ⎣5  6 ⎦

# %%
B_T=B.T
Matrix(B_T)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %%
C=np.random.randn(2,2)
S=C+C.T
S
# Out:
# array([[-1.31794675, -0.22986786],
#        [-0.22986786, -0.63664883]])

# %%
S.T
# Out:
# array([[-1.31794675, -0.22986786],
#        [-0.22986786, -0.63664883]])

# %%
Matrix(np.diag(np.array([1,2,3])))
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  2  0⎥
# ⎢       ⎥
# ⎣0  0  3⎦

# %%
Matrix(np.eye(3).astype(int))
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
# Matrix multiplication of B and A
D= B @ A
D
# Out:
# array([[  6,   4],
#        [ -2, -10]])

# %% [markdown]
# # Outer Product of these matrix

# %%
u= np.array([[1],[2],[3],[4]])
u
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
v= np.array([[0],[1],[2],[3],[6]])
v
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [6]])

# %%
u @ v.T
# Out:
# array([[ 0,  1,  2,  3,  6],
#        [ 0,  2,  4,  6, 12],
#        [ 0,  3,  6,  9, 18],
#        [ 0,  4,  8, 12, 24]])

# %% [markdown]
# Create a matrix with 4 columns where each even column is the vector $\mathbf{u}$, else it is a vector of zeros. Show that the rank of this matrix is one.

# %%
u=np.array([[1],[2]])
print(u)

U = Matrix(u@np.array([[0,1,0,1]]))
print('The rank is: ' + str(matrix_rank(np.array(U).astype(float))))
U
# Out:
# [[1]
#  [2]]
# The rank is: 1
# ⎡0  1  0  1⎤
# ⎢          ⎥
# ⎣0  2  0  2⎦

# %% [markdown]
# Create a matrix with 6 columns where each odd column is twice the vector $\mathbf{u}$, else it is a vector of zeros. Show that the rank of this matrix is one.

# %%
u=np.array([[1],[2]])
print(u)

U = Matrix(u@(2*np.array([[1,0,1,0,1,0]])))
print('The rank is: ' + str(matrix_rank(np.array(U).astype(float))))
U
# Out:
# [[1]
#  [2]]
# The rank is: 1
# ⎡2  0  2  0  2  0⎤
# ⎢                ⎥
# ⎣4  0  4  0  4  0⎦

# %%
A=np.array([[0,-1],[1,0]])
Matrix(A)
# Out:
# ⎡0  -1⎤
# ⎢     ⎥
# ⎣1  0 ⎦

# %%
x=np.array([1,1])
x
# Out:
# array([1, 1])

# %%
b= A@ x
b
# Out:
# array([-1,  1])

# %%
fig, ax = plt.subplots(figsize = (12, 7))
ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=10,label="$\mathbf{a}_{1}$")
ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=10,label="$\mathbf{a}_{2}$")
ax.quiver([0,0],[0,0],b[0], b[1],scale=10,label="$\mathbf{b}$",color='r')
ax.quiver([0,0],[0,0],x[0], x[1],scale=10,label="$\mathbf{x}$",color='b')
ax.set_xlim([-10,10])
ax.set_ylim([-5,10])
fig.legend()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2860180631.py:2: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=10,label="$\mathbf{a}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2860180631.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=10,label="$\mathbf{a}_{2}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2860180631.py:4: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0,0],[0,0],b[0], b[1],scale=10,label="$\mathbf{b}$",color='r')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\2860180631.py:5: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0,0],[0,0],x[0], x[1],scale=10,label="$\mathbf{x}$",color='b')

# %%
E=np.array([[6,-1,3],[1,4,6], [3,5,2]])
Matrix(E)
# Out:
# ⎡6  -1  3⎤
# ⎢        ⎥
# ⎢1  4   6⎥
# ⎢        ⎥
# ⎣3  5   2⎦

# %%
E_inv= inv(E)
F= np.round(E_inv, 4)
Matrix(F)
# Out:
# ⎡0.1302   -0.1006  0.1065 ⎤
# ⎢                         ⎥
# ⎢-0.0947  -0.0178  0.1953 ⎥
# ⎢                         ⎥
# ⎣0.0414   0.1953   -0.1479⎦

# %%
E_inv@E
# Out:
# array([[ 1.00000000e+00,  6.93889390e-17,  8.32667268e-17],
#        [ 8.32667268e-17,  1.00000000e+00,  5.55111512e-17],
#        [ 2.77555756e-17, -2.77555756e-17,  1.00000000e+00]])

# %%
eigen_values , eigen_vectors = eig(E)
Matrix(np.diag(eigen_values))
# Out:
# ⎡9.49228756948933        0.0               0.0       ⎤
# ⎢                                                    ⎥
# ⎢      0.0         5.65568344272856        0.0       ⎥
# ⎢                                                    ⎥
# ⎣      0.0               0.0         -3.1479710122179⎦

# %%
Matrix(eigen_vectors)
# Out:
# ⎡-0.317218028581002  -0.708704203523716  -0.309689341792445⎤
# ⎢                                                          ⎥
# ⎢-0.725269936752109  0.640884139613385   -0.585525346994861⎥
# ⎢                                                          ⎥
# ⎣-0.611028838261154  0.294967577031489   0.749167924838423 ⎦

# %%
E=np.round(eigen_vectors@np.diag(eigen_values)@inv(eigen_vectors),8)
Matrix(E)
# Out:
# ⎡6.0  -1.0  3.0⎤
# ⎢              ⎥
# ⎢1.0  4.0   6.0⎥
# ⎢              ⎥
# ⎣3.0  5.0   2.0⎦

# %%
A=np.round(eigen_vectors@np.diag(eigen_values)@inv(eigen_vectors),8)
Matrix(A)
# Out:
# ⎡6.0  -1.0  3.0⎤
# ⎢              ⎥
# ⎢1.0  4.0   6.0⎥
# ⎢              ⎥
# ⎣3.0  5.0   2.0⎦

# %%
samples=200

u=np.array([[1.0,1.0],[0.10,-0.10]])/(2)**(0.5)

X_=np.dot(4*np.random.randn(samples,2),u)+10
X_[0:5]
# Out:
# array([[ 3.99101003,  3.50133725],
#        [ 9.52036258, 10.11604747],
#        [ 9.57505315,  9.47256432],
#        [13.49962567, 13.4100008 ],
#        [ 9.24625115, 10.47888067]])

# %%
dict_={"design matrix samples":X_}
plot_2da(dict_)

# %%
N,D=X_.shape
print("number of smaples {}, dimensions is {}".format(N,D))
# Out:
# number of smaples 200, dimensions is 2

# %%
mean=(np.ones((1,N))/N)@X_
mean
# Out:
# array([[10.28229268, 10.26408253]])

# %%
X_.mean(axis=0)
# Out:
# array([10.28229268, 10.26408253])

# %%
I=np.identity(N)
col1=np.ones((1,N))
row1=np.ones((N,1))/N
no_mean=(I-row1@col1)

X=no_mean@X_
print("mean of X",X.mean(axis=0))
# Out:
# mean of X [ 6.70574707e-16 -2.34701147e-15]

# %%
dict_={"original data":X_,"zero mean data":X,"mean of original data":mean}
plot_2da(dict_)

# %%
C=X.T@X/N
Matrix(C)
# Out:
# ⎡9.7546953155781   9.54045953778229⎤
# ⎢                                  ⎥
# ⎣9.54045953778229  9.60525430044654⎦

# %%
print(matrix_rank(C))
# Out:
# 2

# %%
print(X.shape)
# Out:
# (200, 2)

# %%
v= np.array([[1,2],[3,2]])

# %%
Z=X@v
z
# Out:
# array([[-3.   , -2.975, -2.95 , ..., -1.575, -1.55 , -1.525],
#        [-2.925, -2.9  , -2.875, ..., -1.5  , -1.475, -1.45 ],
#        [-2.85 , -2.825, -2.8  , ..., -1.425, -1.4  , -1.375],
#        ...,
#        [ 1.275,  1.3  ,  1.325, ...,  2.7  ,  2.725,  2.75 ],
#        [ 1.35 ,  1.375,  1.4  , ...,  2.775,  2.8  ,  2.825],
#        [ 1.425,  1.45 ,  1.475, ...,  2.85 ,  2.875,  2.9  ]],
#       shape=(60, 60))

# %%
pca = PCA(n_components=1)
Z_sklearn = pca.fit_transform(X_)

# This will print True if the vectors are identical (ignoring the sign) and False otherwise
if np.isclose(Z,Z_sklearn).min():
    print(np.isclose(Z,Z_sklearn).min())
else:
    print(np.isclose(Z,-Z_sklearn).min())
# Out:
# False

# %%
pca = PCA(n_components=1)
X_transformed=pca.fit_transform(X)
X_=pca.inverse_transform(X_transformed)

# %%
Xhat=Z@v.T

# %%
import matplotlib.pyplot as plt

def plot_2db(dict_):

    plt.figure(figsize=(8,8))

    for key, value in dict_.items():

        # Scatter plot for datasets
        if value.shape[0] > 2:

            plt.scatter(
                value[:,0],
                value[:,1],
                label=key
            )

        # Vector plot
        else:

            plt.quiver(
                [0,0],          # x origins
                [0,0],          # y origins
                value[:,0],     # x components
                value[:,1],     # y components
                angles='xy',
                scale_units='xy',
                scale=1,
                label=key
            )

    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)

    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")

    plt.legend()
    plt.grid(True)
    plt.axis('equal')

    plt.show()

# %%
dict_ = {
    "Sklearn inverse_transform": X_,
    "Matrix inverse transform": Xhat,
    "First Principal Component": v.T
}

plot_2db(dict_)

# %% [markdown]
# # Now Application on Real dataset

# %%
data = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/Wholesale_Customers_Data.csv', sep=',')
data.head(10)
# Out:
#    Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669   9656     7561     214              2674
# 1        2       3   7057   9810     9568    1762              3293
# 2        2       3   6353   8808     7684    2405              3516
# 3        1       3  13265   1196     4221    6404               507
# 4        2       3  22615   5410     7198    3915              1777
# 5        2       3   9413   8259     5126     666              1795
# 6        2       3  12126   3199     6975     480              3140
# 7        2       3   7579   4956     9426    1669              3321
# 8        1       3   5963   3648     6192     425              1716
# 9        2       3   6006  11093    18881    1159              7425
#
#    Delicassen
# 0        1338
# 1        1776
# 2        7844
# 3        1788
# 4        5185
# 5        1451
# 6         545
# 7        2566
# 8         750
# 9        2098

# %% [markdown]
# We will be using customer data from a [Portuguese wholesale distributor](https://archive.ics.uci.edu/ml/datasets/Wholesale+customers) for clustering. This data file is called `Wholesale_Customers_Data`.
#
# It contains the following features:
#
# * Fresh: annual spending (m.u.) on fresh products
# * Milk: annual spending (m.u.) on milk products
# * Grocery: annual spending (m.u.) on grocery products
# * Frozen: annual spending (m.u.) on frozen products
# * Detergents_Paper: annual spending (m.u.) on detergents and paper products
# * Delicatessen: annual spending (m.u.) on delicatessen products
# * Channel: customer channel (1: hotel/restaurant/cafe or 2: retail)
# * Region: customer region (1: Lisbon, 2: Porto, 3: Other)
#
# In this data, the values for all spending are given in an arbitrary unit (m.u. = monetary unit).

# %%
data.shape
# Out:
# (440, 8)

# %%
data.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %% [markdown]
# ## Part 1
#
# In this section, we will:
#
# * Import the data and check the data types.
# * Drop the channel and region columns as they won't be used since we focus on numeric columns for this example.
# * Convert the remaining columns to floats if necessary.
# * Copy this version of the data (using the `copy` method) to a variable to preserve it. We will be using it later.
#
# ## Part 2
#
# As with the previous lesson, we need to ensure the data is scaled and (relatively) normally distributed.
#
# * Examine the correlation and skew.
# * Perform any transformations and scale data using your favorite scaling method.
# * View the pairwise correlation plots of the new data.

# %%
data = data.drop(['Channel', 'Region'], axis=1)

# %%
data.dtypes
# Out:
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
for col in data.columns:
    data[col] = data[col].astype(np.float64)

# %%
data_orig = data.copy()

# %%
data.dtypes
# Out:
# Fresh               float64
# Milk                float64
# Grocery             float64
# Frozen              float64
# Detergents_Paper    float64
# Delicassen          float64
# dtype: object

# %%
corr_mat= data.corr()

for x in range(corr_mat.shape[0]):
    corr_mat.iloc[x,x] = 0.0

corr_mat
# Out:
#                      Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# Fresh             0.000000  0.100510 -0.011854  0.345881         -0.101953
# Milk              0.100510  0.000000  0.728335  0.123994          0.661816
# Grocery          -0.011854  0.728335  0.000000 -0.040193          0.924641
# Frozen            0.345881  0.123994 -0.040193  0.000000         -0.131525
# Detergents_Paper -0.101953  0.661816  0.924641 -0.131525          0.000000
# Delicassen        0.244690  0.406368  0.205497  0.390947          0.069291
#
#                   Delicassen
# Fresh               0.244690
# Milk                0.406368
# Grocery             0.205497
# Frozen              0.390947
# Detergents_Paper    0.069291
# Delicassen          0.000000

# %%
corr_mat.abs().idxmax()
# Out:
# Fresh                         Frozen
# Milk                         Grocery
# Grocery             Detergents_Paper
# Frozen                    Delicassen
# Detergents_Paper             Grocery
# Delicassen                      Milk
# dtype: object

# %%
data.skew()
# Out:
# Fresh                2.561323
# Milk                 4.053755
# Grocery              3.587429
# Frozen               5.907986
# Detergents_Paper     3.631851
# Delicassen          11.151586
# dtype: float64

# %%
log_columns = data.skew().sort_values(ascending=False)
log_columns = log_columns.loc[log_columns > 0.75]

log_columns
# Out:
# Delicassen          11.151586
# Frozen               5.907986
# Milk                 4.053755
# Detergents_Paper     3.631851
# Grocery              3.587429
# Fresh                2.561323
# dtype: float64

# %%
log_data = np.log1p(data)

# %%
log_data.skew()
# Out:
# Fresh              -1.575326
# Milk               -0.224063
# Grocery            -0.674938
# Frozen             -0.352655
# Detergents_Paper   -0.235961
# Delicassen         -1.091827
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()

for col in data.columns:
    data[col] = mms.fit_transform(data[[col]]).squeeze()

# %%
data.skew()
# Out:
# Fresh                2.561323
# Milk                 4.053755
# Grocery              3.587429
# Frozen               5.907986
# Detergents_Paper     3.631851
# Delicassen          11.151586
# dtype: float64

# %%
sns.set_context('notebook')
sns.set_style('white')
sns.pairplot(data);

# %% [markdown]
# ## Part 3
#
# In this section, we will:
# * Using Scikit-learn's [pipeline function](http://scikit-learn.org/stable/modules/pipeline.html), recreate the data pre-processing scheme above (transformation and scaling) using a pipeline. If you used a non-Scikit learn function to transform the data (e.g. NumPy's log function), checkout  the custom transformer class called [`FunctionTransformer`](http://scikit-learn.org/stable/modules/preprocessing.html#custom-transformers).
# * Use the pipeline to transform the original data that was stored at the end of question 1.
# * Compare the results to the original data to verify that everything worked.
#
# *Note:* Scikit-learn has a more flexible `Pipeline` function and a shortcut version called `make_pipeline`. Either can be used. Also, if different transformations need to be performed on the data, a [`FeatureUnion`](http://scikit-learn.org/stable/modules/pipeline.html#featureunion-composite-feature-spaces) can be used.

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline

# The custom NumPy log transformer
log_transformer = FunctionTransformer(np.log1p)

# The pipeline
estimators = [('log1p', log_transformer), ('minmaxscale', MinMaxScaler())]
pipeline = Pipeline(estimators)

# Convert the original data
data_pipe = pipeline.fit_transform(data_orig)

# %%
np.allclose(data_pipe, data)
# Out:
# False

# %% [markdown]
# ## Part 4
#
# In this section, we will:
# * Perform PCA with `n_components` ranging from 1 to 5.
# * Store the amount of explained variance for each number of dimensions.
# * Also store the feature importance for each number of dimensions. *Hint:* PCA doesn't explicitly provide this after a model is fit, but the `components_` properties can be used to determine something that approximates importance. How you decided to do so is entirely up to you.
# * Plot the explained variance and feature importances.

# %%
from sklearn.decomposition import PCA

pca_list = list()
feature_weight_list = list()

# Fit a range of PCA models

for n in range(1, 6):
    
    # Create and fit the model
    PCAmod = PCA(n_components=n)
    PCAmod.fit(data)
    
    # Store the model and variance
    pca_list.append(pd.Series({'n':n, 'model':PCAmod,
                               'var': PCAmod.explained_variance_ratio_.sum()}))
    
    # Calculate and store feature importances
    abs_feature_values = np.abs(PCAmod.components_).sum(axis=0)
    feature_weight_list.append(pd.DataFrame({'n':n, 
                                             'features': data.columns,
                                             'values':abs_feature_values/abs_feature_values.sum()}))
    
pca_df = pd.concat(pca_list, axis=1).T.set_index('n')
pca_df
# Out:
#                  model       var
# n
# 1  PCA(n_components=1)  0.519483
# 2  PCA(n_components=2)  0.783553
# 3  PCA(n_components=3)  0.889614
# 4  PCA(n_components=4)  0.952194
# 5  PCA(n_components=5)  0.987169

# %%
pca_df.head(10)
# Out:
#                  model       var
# n
# 1  PCA(n_components=1)  0.519483
# 2  PCA(n_components=2)  0.783553
# 3  PCA(n_components=3)  0.889614
# 4  PCA(n_components=4)  0.952194
# 5  PCA(n_components=5)  0.987169

# %%
features_df = (pd.concat(feature_weight_list)
               .pivot(index='n', columns='features', values='values'))

features_df
# Out:
# features  Delicassen  Detergents_Paper     Fresh    Frozen   Grocery      Milk
# n
# 1           0.044814          0.353473  0.010118  0.009502  0.314499  0.267594
# 2           0.082579          0.213766  0.243582  0.114369  0.160125  0.185579
# 3           0.117570          0.171344  0.238340  0.184697  0.114829  0.173220
# 4           0.121701          0.170542  0.178478  0.212652  0.109540  0.207087
# 5           0.185339          0.145091  0.146338  0.194828  0.111005  0.217399

# %%
sns.set_context('talk')
ax = pca_df['var'].plot(kind='bar')

ax.set(xlabel='Number of dimensions',
       ylabel='Percent explained variance',
       title='Explained Variance vs Dimensions');

# %%
ax = features_df.plot(kind='bar', figsize=(13,8))
ax.legend(loc='upper right')
ax.set(xlabel='Number of dimensions',
       ylabel='Relative importance',
       title='Feature importance vs Dimensions');

# %%
# ---------------------------------------------
# Create Knee Plot using PCA explained variance
# ---------------------------------------------

ax = pca_df['var'].plot(
    kind='line',
    marker='o',
    figsize=(13,8)
)

# ---------------------------------------------
# Labels and title
# ---------------------------------------------
ax.set(
    xlabel='Number of Principal Components',
    ylabel='Cumulative Explained Variance',
    title='PCA Knee Plot'
)

# ---------------------------------------------
# Grid
# ---------------------------------------------
plt.grid(True)

plt.show()

# %% [markdown]
# # Day3: using PCA on wholesale consumer data

# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/Wholesale_Customers_Data.csv', sep=',')
data1.head(10)
# Out:
#    Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669   9656     7561     214              2674
# 1        2       3   7057   9810     9568    1762              3293
# 2        2       3   6353   8808     7684    2405              3516
# 3        1       3  13265   1196     4221    6404               507
# 4        2       3  22615   5410     7198    3915              1777
# 5        2       3   9413   8259     5126     666              1795
# 6        2       3  12126   3199     6975     480              3140
# 7        2       3   7579   4956     9426    1669              3321
# 8        1       3   5963   3648     6192     425              1716
# 9        2       3   6006  11093    18881    1159              7425
#
#    Delicassen
# 0        1338
# 1        1776
# 2        7844
# 3        1788
# 4        5185
# 5        1451
# 6         545
# 7        2566
# 8         750
# 9        2098

# %%
X= data1.drop(['Channel'], axis=1)

# %%
data1.shape
# Out:
# (440, 8)

# %%
X
# Out:
#      Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0         3  12669   9656     7561     214              2674        1338
# 1         3   7057   9810     9568    1762              3293        1776
# 2         3   6353   8808     7684    2405              3516        7844
# 3         3  13265   1196     4221    6404               507        1788
# 4         3  22615   5410     7198    3915              1777        5185
# ..      ...    ...    ...      ...     ...               ...         ...
# 435       3  29703  12051    16027   13135               182        2204
# 436       3  39228   1431      764    4510                93        2346
# 437       3  14531  15488    30243     437             14841        1867
# 438       3  10290   1981     2232    1038               168        2125
# 439       3   2787   1698     2510      65               477          52
#
# [440 rows x 7 columns]

# %%
y = data1['Channel']
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      2
#       ..
# 435    1
# 436    1
# 437    2
# 438    1
# 439    1
# Name: Channel, Length: 440, dtype: int64

# %%
# Stratified split
sss = StratifiedShuffleSplit(
    n_splits=5,
    test_size=0.2,
    random_state=42
)

# %%
def get_avg_score(n):
    
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('pca', PCA(n_components=n)),
        ('estimator', LogisticRegression(solver='liblinear'))
    ])

    scores = []

    for train_index, test_index in sss.split(X, y):

        X_train = X.iloc[train_index]
        X_test  = X.iloc[test_index]

        y_train = y.iloc[train_index]
        y_test  = y.iloc[test_index]

        pipe.fit(X_train, y_train)

        preds = pipe.predict(X_test)

        scores.append(
            accuracy_score(y_test, preds)
        )

    return np.mean(scores)


# Valid PCA components
ns = [1, 2, 3, 4, 5, 6, 7]

score_list = [get_avg_score(n) for n in ns]

print(score_list)
# Out:
# [np.float64(0.8545454545454545), np.float64(0.884090909090909), np.float64(0.8931818181818183), np.float64(0.8886363636363637), np.float64(0.890909090909091), np.float64(0.884090909090909), np.float64(0.8931818181818182)]

# %%
# Plot
sns.set_context('talk')

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(
    ns,
    score_list,
    marker='o',
    linewidth=2
)

ax.set(
    xlabel='Number of PCA Components',
    ylabel='Average Accuracy',
    title='Logistic Regression Accuracy vs PCA Dimensions'
)

ax.grid(True)

plt.show()

# %% [markdown]
# # Simple PCA on energydata

# %%
df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/data/energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %% [markdown]
# The columns can be described as follows:
#
# *   `Appliances` - energy use of appliances in Wh
# *   `lights` - energy use of light fixtures in the house in Wh
# *   `T1` - Temperature in kitchen area, in Celsius
# *   `RH_1` - Humidity in kitchen area, in $%$
# *   `T2` - Temperature in living room area, in Celsius
# *   `RH_2` - Humidity in living room area, in $%$
# *   $\dots$
# *   `To` - Temperature outside (from Chievres weather station), in Celsius
# *   `Pressure` - (from Chievres weather station), in mm Hg
# *   `RH_out` - Humidity outside (from Chievres weather station), in %
# *   `Wind speed` - (from Chievres weather station), in m/s
# *   `Visibility` - (from Chievres weather station), in km
# *   `Tdewpoint` - (from Chievres weather station), Â°C
# *   `rv1`, `rv2` - Random variable 1 & 2, nondimensional
#
# Please see the [data source](https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for more information.

# %%
df= df.drop('date', axis=1)
df.dropna().astype(np.float64)
df.head()
# Out:
#    Appliances  lights     T1       RH_1    T2       RH_2     T3       RH_3  \
# 0          60      30  19.89  47.596667  19.2  44.790000  19.79  44.730000
# 1          60      30  19.89  46.693333  19.2  44.722500  19.79  44.790000
# 2          50      30  19.89  46.300000  19.2  44.626667  19.79  44.933333
# 3          50      40  19.89  46.066667  19.2  44.590000  19.79  45.000000
# 4          60      40  19.89  46.333333  19.2  44.530000  19.79  45.000000
#
#           T4       RH_4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.000000  45.566667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  19.000000  45.992500  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  18.926667  45.890000  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  18.890000  45.723333  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  18.890000  45.530000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
# 2   6.333333   55.333333        5.1  28.642668  28.642668
# 3   6.000000   51.500000        5.0  45.410389  45.410389
# 4   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 28 columns]

# %%
scaler = StandardScaler()
df[:] = scaler.fit_transform(df)
df.head()
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\3850264742.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.36767572 -0.36767572 -0.46521548 ...  1.68065927  3.14375569
#   3.24129545]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[:] = scaler.fit_transform(df)
# C:\Users\BIT\AppData\Local\Temp\ipykernel_23980\3850264742.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[3.30126384 3.30126384 3.30126384 ... 0.78103476 0.78103476 0.78103476]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[:] = scaler.fit_transform(df)
#    Appliances    lights        T1      RH_1        T2      RH_2        T3  \
# 0   -0.367676  3.301264 -1.118645  1.843821 -0.520411  1.073683 -1.235063
# 1   -0.367676  3.301264 -1.118645  1.616807 -0.520411  1.057097 -1.235063
# 2   -0.465215  3.301264 -1.118645  1.517959 -0.520411  1.033550 -1.235063
# 3   -0.465215  4.561378 -1.118645  1.459321 -0.520411  1.024540 -1.235063
# 4   -0.367676  4.561378 -1.118645  1.526336 -0.520411  1.009797 -1.235063
#
#        RH_3        T4      RH_4  ...        T9      RH_9     T_out  \
# 0  1.686130 -0.908217  1.506438  ... -1.217324  0.958136 -0.152647
# 1  1.704566 -0.908217  1.604528  ... -1.200778  0.965363 -0.174588
# 2  1.748608 -0.944115  1.580918  ... -1.233869  0.950910 -0.196529
# 3  1.769092 -0.962063  1.542526  ... -1.233869  0.926821 -0.218470
# 4  1.769092 -0.962063  1.497991  ... -1.233869  0.926821 -0.240411
#
#    Press_mm_hg   RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# 0    -2.976328  0.82208   1.207694    2.091596   0.366975 -0.807974 -0.807974
# 1    -2.962813  0.82208   1.071703    1.766584   0.343135 -0.440240 -0.440240
# 2    -2.949298  0.82208   0.935713    1.441572   0.319294  0.252109  0.252109
# 3    -2.935783  0.82208   0.799723    1.116559   0.295454  1.408801  1.408801
# 4    -2.922268  0.82208   0.663733    0.791547   0.271613 -1.028122 -1.028122
#
# [5 rows x 28 columns]

# %%
pca=PCA()
pca.fit(df)
# Out:
# PCA()

# %%
x= np.argwhere(pca.explained_variance_ratio_.cumsum() >= 0.95)[0][0] + 1
x
# Out:
# np.int64(12)

# %%
pca = PCA(n_components=12)
reduced_data = pca.fit(df).transform(df)

# %%
pd.DataFrame(reduced_data, columns=[f'Component {i}' for i in range(reduced_data.shape[1])]).head()
# Out:
#    Component 0  Component 1  Component 2  Component 3  Component 4  \
# 0    -2.922039     4.688402    -1.548784     1.200384     1.953325
# 1    -2.940551     4.617382    -1.026564     1.273485     1.958929
# 2    -2.983922     4.532971    -0.057812     1.455761     1.925351
# 3    -3.074540     4.511345     1.503160     1.955986     2.803530
# 4    -3.050297     4.486200    -1.798191     0.976510     2.843927
#
#    Component 5  Component 6  Component 7  Component 8  Component 9  \
# 0    -0.372920     2.529788     0.640358     2.475223    -0.748954
# 1    -0.495274     2.237205     0.583417     2.463552    -0.854024
# 2    -0.626959     1.941323     0.559629     2.499994    -0.949800
# 3    -0.560489     1.565011     0.474951     3.320774    -1.015321
# 4    -0.700518     1.271911     0.287486     3.287537    -1.118611
#
#    Component 10  Component 11
# 0     -1.448401     -0.514303
# 1     -1.437129     -0.443660
# 2     -1.460569     -0.450196
# 3     -1.598426     -0.410259
# 4     -1.607082     -0.419324
