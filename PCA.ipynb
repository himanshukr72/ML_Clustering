# %% [markdown]
# # PCA Code:

# %%
import numpy as np 
import matplotlib.pylab as plt

from sklearn.decomposition import PCA
from sympy import Matrix, init_printing,Symbol
from numpy.linalg import qr,eig,inv,matrix_rank,inv, norm
from scipy.linalg import null_space
init_printing()

# %%
def plot_2da(dict_):
    for key, value in dict_.items():
        plt.scatter(value[:, 0], value[:, 1],label=key)
    plt.legend()
    plt.show()
    
def plot_2db(dict_):
    for key, value in dict_.items():
        if value.shape[0]>2:
            plt.scatter(value[:, 0], value[:, 1],label=key)
        else:
            print(value)
            plt.quiver([0],[0],value[:,0],value[:,1],label=key)
    plt.legend()
    plt.show()

# %%
A=np.array([[2,-3],[4,7]])

Matrix(A)
# Out:
# ⎡2  -3⎤
# ⎢     ⎥
# ⎣4  7 ⎦

# %%
a1=A[:,0]
a1
# Out:
# array([2, 4])

# %%
a2=A[:,1]
a2
# Out:
# array([-3,  7])

# %%
AT=A.T
Matrix(AT)
# Out:
# ⎡2   4⎤
# ⎢     ⎥
# ⎣-3  7⎦

# %%
matrix_rank(A)
# Out:
# np.int64(2)

# %%
fig, ax = plt.subplots(figsize = (12, 7))

ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=30,label="$\mathbf{a}_{1}$")
ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=30,label="$\mathbf{a}_{2}$",color='red')
plt.title("columns of $\mathbf{A}$ ")
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\3086253123.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=30,label="$\mathbf{a}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\3086253123.py:4: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=30,label="$\mathbf{a}_{2}$",color='red')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\3086253123.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("columns of $\mathbf{A}$ ")

# %%
F=np.array([[2,4],[4,8]])
matrix_rank(F)
# Out:
# np.int64(1)

# %%
fig, ax = plt.subplots(figsize = (12, 7))
ax.quiver([0, 0],[0, 0],F[0,1], F[1,1],scale=30,label="$\mathbf{f}_{2}$",color='red')
ax.quiver([0, 0],[0, 0],F[0,0], F[1,0],scale=30,label="$\mathbf{f}_{1}$")
plt.title("columns of $\mathbf{F}$ ")
plt.legend()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2808504675.py:2: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],F[0,1], F[1,1],scale=30,label="$\mathbf{f}_{2}$",color='red')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2808504675.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],F[0,0], F[1,0],scale=30,label="$\mathbf{f}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2808504675.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("columns of $\mathbf{F}$ ")

# %%
G=np.array([[2,4,6],[6,4,2],[16,16,16]])

print(G)
print('Rank is:')
print(matrix_rank(G))
# Out:
# [[ 2  4  6]
#  [ 6  4  2]
#  [16 16 16]]
# Rank is:
# 2

# %%
F=np.array([[1,2],[1,-2],[-1,1]])
Matrix(F)
# Out:
# ⎡1   2 ⎤
# ⎢      ⎥
# ⎢1   -2⎥
# ⎢      ⎥
# ⎣-1  1 ⎦

# %%
ax = plt.figure().add_subplot(projection='3d')
p=null_space(F.T)
xx, yy = np.meshgrid(np.arange(-3,3,0.1), np.arange(-3,3,0.1))
z=(p[0]*xx+p[1]*yy)/p[2]
ax.plot_surface(xx, yy, z, alpha=0.1)
ax.quiver([0,0], [0,0], [0,0], F[0,:], F[1,:], F[2,:])

ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])
plt.show()

# %%
matrix_rank(F)
# Out:
# np.int64(2)

# %% [markdown]
# ### Frobenius norm of a matrix

# %%
Matrix(A), norm(A)
# Out:
# ⎛⎡2  -3⎤                   ⎞
# ⎜⎢     ⎥, 8.831760866327848⎟
# ⎝⎣4  7 ⎦                   ⎠

# %%
m, n = A.shape[0], A.shape[1] # get number of rows and columns 
sumsquares = 0

for i in range(m):
    for j in range(n):
        sumsquares += A[i,j] ** 2
np.sqrt(sumsquares)
# Out:
# np.float64(8.831760866327848)

# %%
B=np.array([[1,1],[1,-1]])
Matrix(B)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %%
C=A+B
Matrix(C)
# Out:
# ⎡3  -2⎤
# ⎢     ⎥
# ⎣5  6 ⎦

# %%
B_T=B.T
Matrix(B_T)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %%
C=np.random.randn(2,2)
S=C+C.T
S
# Out:
# array([[-3.48165758,  0.39635174],
#        [ 0.39635174,  2.29360152]])

# %%
S.T
# Out:
# array([[-3.48165758,  0.39635174],
#        [ 0.39635174,  2.29360152]])

# %%
Matrix(np.diag(np.array([1,2,3])))
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  2  0⎥
# ⎢       ⎥
# ⎣0  0  3⎦

# %%
Matrix(np.eye(3).astype(int))
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
# Matrix multiplication of B and A
D= B @ A
D
# Out:
# array([[  6,   4],
#        [ -2, -10]])

# %% [markdown]
# # Outer Product of these matrix

# %%
u= np.array([[1],[2],[3],[4]])
u
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
v= np.array([[0],[1],[2],[3],[6]])
v
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [6]])

# %%
u @ v.T
# Out:
# array([[ 0,  1,  2,  3,  6],
#        [ 0,  2,  4,  6, 12],
#        [ 0,  3,  6,  9, 18],
#        [ 0,  4,  8, 12, 24]])

# %% [markdown]
# Create a matrix with 4 columns where each even column is the vector $\mathbf{u}$, else it is a vector of zeros. Show that the rank of this matrix is one.

# %%
u=np.array([[1],[2]])
print(u)

U = Matrix(u@np.array([[0,1,0,1]]))
print('The rank is: ' + str(matrix_rank(np.array(U).astype(float))))
U
# Out:
# [[1]
#  [2]]
# The rank is: 1
# ⎡0  1  0  1⎤
# ⎢          ⎥
# ⎣0  2  0  2⎦

# %% [markdown]
# Create a matrix with 6 columns where each odd column is twice the vector $\mathbf{u}$, else it is a vector of zeros. Show that the rank of this matrix is one.

# %%
u=np.array([[1],[2]])
print(u)

U = Matrix(u@(2*np.array([[1,0,1,0,1,0]])))
print('The rank is: ' + str(matrix_rank(np.array(U).astype(float))))
U
# Out:
# [[1]
#  [2]]
# The rank is: 1
# ⎡2  0  2  0  2  0⎤
# ⎢                ⎥
# ⎣4  0  4  0  4  0⎦

# %%
A=np.array([[0,-1],[1,0]])
Matrix(A)
# Out:
# ⎡0  -1⎤
# ⎢     ⎥
# ⎣1  0 ⎦

# %%
x=np.array([1,1])
x
# Out:
# array([1, 1])

# %%
b= A@ x
b
# Out:
# array([-1,  1])

# %%
fig, ax = plt.subplots(figsize = (12, 7))
ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=10,label="$\mathbf{a}_{1}$")
ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=10,label="$\mathbf{a}_{2}$")
ax.quiver([0,0],[0,0],b[0], b[1],scale=10,label="$\mathbf{b}$",color='r')
ax.quiver([0,0],[0,0],x[0], x[1],scale=10,label="$\mathbf{x}$",color='b')
ax.set_xlim([-10,10])
ax.set_ylim([-5,10])
fig.legend()
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2860180631.py:2: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,0], A[1,0],scale=10,label="$\mathbf{a}_{1}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2860180631.py:3: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0, 0],[0, 0],A[0,1], A[1,1],scale=10,label="$\mathbf{a}_{2}$")
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2860180631.py:4: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0,0],[0,0],b[0], b[1],scale=10,label="$\mathbf{b}$",color='r')
# C:\Users\BIT\AppData\Local\Temp\ipykernel_20628\2860180631.py:5: SyntaxWarning: invalid escape sequence '\m'
#   ax.quiver([0,0],[0,0],x[0], x[1],scale=10,label="$\mathbf{x}$",color='b')

# %%
E=np.array([[6,-1,3],[1,4,6], [3,5,2]])
Matrix(E)
# Out:
# ⎡6  -1  3⎤
# ⎢        ⎥
# ⎢1  4   6⎥
# ⎢        ⎥
# ⎣3  5   2⎦

# %%
E_inv= inv(E)
F= np.round(E_inv, 4)
Matrix(F)
# Out:
# ⎡0.1302   -0.1006  0.1065 ⎤
# ⎢                         ⎥
# ⎢-0.0947  -0.0178  0.1953 ⎥
# ⎢                         ⎥
# ⎣0.0414   0.1953   -0.1479⎦

# %%
E_inv@E
# Out:
# array([[ 1.00000000e+00,  6.93889390e-17,  8.32667268e-17],
#        [ 8.32667268e-17,  1.00000000e+00,  5.55111512e-17],
#        [ 2.77555756e-17, -2.77555756e-17,  1.00000000e+00]])

# %%
eigen_values , eigen_vectors = eig(E)
Matrix(np.diag(eigen_values))
# Out:
# ⎡9.49228756948933        0.0               0.0       ⎤
# ⎢                                                    ⎥
# ⎢      0.0         5.65568344272856        0.0       ⎥
# ⎢                                                    ⎥
# ⎣      0.0               0.0         -3.1479710122179⎦

# %%
Matrix(eigen_vectors)
# Out:
# ⎡-0.317218028581002  -0.708704203523716  -0.309689341792445⎤
# ⎢                                                          ⎥
# ⎢-0.725269936752109  0.640884139613385   -0.585525346994861⎥
# ⎢                                                          ⎥
# ⎣-0.611028838261154  0.294967577031489   0.749167924838423 ⎦

# %%
E=np.round(eigen_vectors@np.diag(eigen_values)@inv(eigen_vectors),8)
Matrix(E)
# Out:
# ⎡6.0  -1.0  3.0⎤
# ⎢              ⎥
# ⎢1.0  4.0   6.0⎥
# ⎢              ⎥
# ⎣3.0  5.0   2.0⎦

# %%
A=np.round(eigen_vectors@np.diag(eigen_values)@inv(eigen_vectors),8)
Matrix(A)
# Out:
# ⎡6.0  -1.0  3.0⎤
# ⎢              ⎥
# ⎢1.0  4.0   6.0⎥
# ⎢              ⎥
# ⎣3.0  5.0   2.0⎦

# %%
samples=200

u=np.array([[1.0,1.0],[0.10,-0.10]])/(2)**(0.5)

X_=np.dot(4*np.random.randn(samples,2),u)+10
X_[0:5]
# Out:
# array([[ 9.46037342, 10.12716261],
#        [13.45255014, 13.30848898],
#        [10.1273167 , 10.02455833],
#        [ 9.18022688,  8.33348615],
#        [ 8.01840026,  7.15641546]])

# %%
dict_={"design matrix samples":X_}
plot_2da(dict_)

# %%
N,D=X_.shape
print("number of smaples {}, dimensions is {}".format(N,D))
# Out:
# number of smaples 200, dimensions is 2

# %%
mean=(np.ones((1,N))/N)@X_
mean
# Out:
# array([[10.20173067, 10.16615212]])

# %%
X_.mean(axis=0)
# Out:
# array([10.20173067, 10.16615212])

# %%
I=np.identity(N)
col1=np.ones((1,N))
row1=np.ones((N,1))/N
no_mean=(I-row1@col1)

X=no_mean@X_
print("mean of X",X.mean(axis=0))
# Out:
# mean of X [-1.03250741e-15 -1.37667655e-15]

# %%
dict_={"original data":X_,"zero mean data":X,"mean of original data":mean}
plot_2da(dict_)

# %%
C=X.T@X/N
Matrix(C)
# Out:
# ⎡8.41559302485838  8.17902826179406⎤
# ⎢                                  ⎥
# ⎣8.17902826179406  8.24020131545925⎦

# %%
print(matrix_rank(C))
# Out:
# 2

# %%
print(X.shape)
Matrix(X)
# Out:
# (200, 2)
# ⎡ -0.741357243953832   -0.0389895074412667⎤
# ⎢                                         ⎥
# ⎢  3.25081946980777     3.14233686050943  ⎥
# ⎢                                         ⎥
# ⎢-0.0744139651650171   -0.141593790544611 ⎥
# ⎢                                         ⎥
# ⎢  -1.021503787439      -1.83266597608044 ⎥
# ⎢                                         ⎥
# ⎢ -2.18333040907966     -3.00973666244581 ⎥
# ⎢                                         ⎥
# ⎢ -3.34215281947134     -3.39388293786666 ⎥
# ⎢                                         ⎥
# ⎢ -0.861263427369893    -1.37181779039523 ⎥
# ⎢                                         ⎥
# ⎢ 0.623036888669149    -0.577574960888654 ⎥
# ⎢                                         ⎥
# ⎢  2.81136651629232      2.5409675342502  ⎥
# ⎢                                         ⎥
# ⎢  4.2715141519595       4.5799435057448  ⎥
# ⎢                                         ⎥
# ⎢  3.35212129429873     4.07230938758933  ⎥
# ⎢                                         ⎥
# ⎢ -3.06521179576771     -2.59414967638636 ⎥
# ⎢                                         ⎥
# ⎢  6.88713477298723     7.33068055833196  ⎥
# ⎢                                         ⎥
# ⎢  3.54188257144371     3.49702640060241  ⎥
# ⎢                                         ⎥
# ⎢ -0.820961358003037    -1.05622839195481 ⎥
# ⎢                                         ⎥
# ⎢ -0.268444427541232    -1.05680936959308 ⎥
# ⎢                                         ⎥
# ⎢ -2.92757547465314     -2.47282508518776 ⎥
# ⎢                                         ⎥
# ⎢  1.24102657951903     1.72826856331492  ⎥
# ⎢                                         ⎥
# ⎢ 0.327386363053005     0.81075002720973  ⎥
# ⎢                                         ⎥
# ⎢  1.39004987699603     0.694457041121998 ⎥
# ⎢                                         ⎥
# ⎢ -2.93569674992842     -1.96469912441173 ⎥
# ⎢                                         ⎥
# ⎢ -1.56968729639233     -1.86805572890826 ⎥
# ⎢                                         ⎥
# ⎢  5.91974870143446     6.08518261125658  ⎥
# ⎢                                         ⎥
# ⎢  2.3698784329824      2.57620865316099  ⎥
# ⎢                                         ⎥
# ⎢ -0.576883599394701   -0.0167478792916729⎥
# ⎢                                         ⎥
# ⎢  3.61853472026191     2.85303631623387  ⎥
# ⎢                                         ⎥
# ⎢ -0.979019056618746    -1.26144439728917 ⎥
# ⎢                                         ⎥
# ⎢ -4.10336555491458     -4.26342150482428 ⎥
# ⎢                                         ⎥
# ⎢ -1.57835973389317     -1.05537237384048 ⎥
# ⎢                                         ⎥
# ⎢ -7.88325475719911     -7.88753102649927 ⎥
# ⎢                                         ⎥
# ⎢ 0.699122869557972     0.312501907367552 ⎥
# ⎢                                         ⎥
# ⎢  2.19826305427346      1.9121213367708  ⎥
# ⎢ -0.05568587345845     0.883897746893319 ⎥
# ⎢                                         ⎥
# ⎢ -3.17457442548738     -2.32807328175935 ⎥
# ⎢                                         ⎥
# ⎢  2.61665011022561     2.43156068173606  ⎥
# ⎢                                         ⎥
# ⎢ -4.20259615661046     -4.44882875477026 ⎥
# ⎢                                         ⎥
# ⎢ -1.16156780836545    0.0458322969860872 ⎥
# ⎢                                         ⎥
# ⎢  2.2663408636393       2.6541050433364  ⎥
# ⎢                                         ⎥
# ⎢  5.14956646725021     5.33229208219082  ⎥
# ⎢                                         ⎥
# ⎢ -1.42099106953689    -0.658629287394645 ⎥
# ⎢                                         ⎥
# ⎢  1.8123153014409      1.87703805591184  ⎥
# ⎢                                         ⎥
# ⎢ -3.45026248746113     -4.48610439030785 ⎥
# ⎢                                         ⎥
# ⎢  2.00118890489144     1.63138828135937  ⎥
# ⎢                                         ⎥
# ⎢  0.19736706318596    -0.0733824771143743⎥
# ⎢                                         ⎥
# ⎢ -2.23215081174018     -2.64909245342358 ⎥
# ⎢                                         ⎥
# ⎢  1.20374021810118     1.47911281747428  ⎥
# ⎢                                         ⎥
# ⎢  3.11789135500465     4.16489905490365  ⎥
# ⎢                                         ⎥
# ⎣ -1.74203612455802     -2.13838563760112 ⎦

# %%
v= np.array([[1,2],[3,2]])

# %%
Z=X@v
z
# Out:
# array([[-3.   , -2.975, -2.95 , ..., -1.575, -1.55 , -1.525],
#        [-2.925, -2.9  , -2.875, ..., -1.5  , -1.475, -1.45 ],
#        [-2.85 , -2.825, -2.8  , ..., -1.425, -1.4  , -1.375],
#        ...,
#        [ 1.275,  1.3  ,  1.325, ...,  2.7  ,  2.725,  2.75 ],
#        [ 1.35 ,  1.375,  1.4  , ...,  2.775,  2.8  ,  2.825],
#        [ 1.425,  1.45 ,  1.475, ...,  2.85 ,  2.875,  2.9  ]],
#       shape=(60, 60))

# %%
pca = PCA(n_components=1)
Z_sklearn = pca.fit_transform(X_)

# This will print True if the vectors are identical (ignoring the sign) and False otherwise
if np.isclose(Z,Z_sklearn).min():
    print(np.isclose(Z,Z_sklearn).min())
else:
    print(np.isclose(Z,-Z_sklearn).min())
# Out:
# False

# %%
pca = PCA(n_components=1)
X_transformed=pca.fit_transform(X)
X_=pca.inverse_transform(X_transformed)

# %%
Xhat=Z@v.T

# %%
import matplotlib.pyplot as plt

def plot_2db(dict_):

    plt.figure(figsize=(8,8))

    for key, value in dict_.items():

        # Scatter plot for datasets
        if value.shape[0] > 2:

            plt.scatter(
                value[:,0],
                value[:,1],
                label=key
            )

        # Vector plot
        else:

            plt.quiver(
                [0,0],          # x origins
                [0,0],          # y origins
                value[:,0],     # x components
                value[:,1],     # y components
                angles='xy',
                scale_units='xy',
                scale=1,
                label=key
            )

    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)

    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")

    plt.legend()
    plt.grid(True)
    plt.axis('equal')

    plt.show()

# %%
dict_ = {
    "Sklearn inverse_transform": X_,
    "Matrix inverse transform": Xhat,
    "First Principal Component": v.T
}

plot_2db(dict_)
